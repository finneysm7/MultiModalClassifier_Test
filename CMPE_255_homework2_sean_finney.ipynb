# %% [markdown]
# # Going with option 2, looking into the different code.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
! ls gdrive
# Out:
# ls: cannot access 'gdrive': No such file or directory

# %%
# %cd gdrive/My Drive/cmpe_255_homework2
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/cmpe_255_homework2'
# /content/gdrive/My Drive/cmpe_255_homework2/MultiModalClassifier

# %%
! git clone https://github.com/lkk688/MultiModalClassifier.git
# Out:
# fatal: destination path 'MultiModalClassifier' already exists and is not an empty directory.

# %%
# %cd MultiModalClassifier
# Out:
# /content/gdrive/My Drive/cmpe_255_homework2/MultiModalClassifier

# %%
! git pull
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
! python setup.py develop
# Out:
# running develop
# /usr/local/lib/python3.10/dist-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
# ...

# %%
! python3 -m pip install configargparse
! python3 -m pip install pip install -q torchinfo #summary in pytorch need this to be installed

# %%
import TFClassifier
import TFClassifier.Datasetutil
import TFClassifier.Datasetutil.Visutil
import configargparse

# %% [markdown]
# # Running data within Pytorch checks
#
# ## I have 2 models running against the data here which should fulfill homework requirements.

# %%
! python TorchClassifier/myTorchTrainer.py --data_name 'CIFAR10' --data_type 'torchvisiondataset' --data_path r"E:\Dataset" --model_name 'cnnmodel1' --learningratename 'MultiStepLR' --optimizer 'SGD'
# Out:
# 2023-12-02 01:16:42.510989: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 01:16:42.511039: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 01:16:42.511076: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 01:16:43.658357: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.1.0+cu118
# Torch Version:  2.1.0+cu118
# Torchvision Version:  0.16.0+cu118
# Output path: ./outputs/CIFAR10_cnnmodel1_0910
# Num GPUs: 1
# 0
# Tesla T4
# True
# Files already downloaded and verified
# ...

# %%
! python TorchClassifier/myTorchTrainer.py --data_name 'CIFAR10' --data_type 'torchvisiondataset' --data_path r"E:\Dataset" --model_name 'resnetmodel1' --learningratename 'MultiStepLR' --optimizer 'SGD'
# Out:
# 2023-12-02 03:48:58.490583: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 03:48:58.490635: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 03:48:58.490675: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 03:48:59.932519: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.1.0+cu118
# Torch Version:  2.1.0+cu118
# Torchvision Version:  0.16.0+cu118
# Output path: ./outputs/CIFAR10_resnetmodel1_0910
# Num GPUs: 1
# 0
# Tesla T4
# True
# ...
# 100% 170498071/170498071 [00:03<00:00, 48450607.34it/s]
# ...

# %% [markdown]
# # Running with image data, different models
# ## Lots of problems with this data as it is too large, haven't run all of it.

# %%
! wget -P /data/cmpe249-fa23/ImageClassData https://image-net.org/data/tiny-imagenet-200.zip
# Out:
# --2023-12-02 02:56:52--  https://image-net.org/data/tiny-imagenet-200.zip
# Resolving image-net.org (image-net.org)... 171.64.68.16
# Connecting to image-net.org (image-net.org)|171.64.68.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘/data/cmpe249-fa23/ImageClassData/tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  16.8MB/s    in 15s
#
# 2023-12-02 02:57:07 (15.7 MB/s) - ‘/data/cmpe249-fa23/ImageClassData/tiny-imagenet-200.zip’ saved [248100043/248100043]

# %%
! unzip /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200.zip -d /data/cmpe249-fa23/ImageClassData/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_3979.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_3963.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_7199.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_2752.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_9687.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_9407.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_3603.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_3412.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_6982.JPEG
#   inflating: /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/val/images/val_8496.JPEG
# ...

# %%
# %cp -r /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/tiny-imagenet-200/. /data/cmpe249-fa23/ImageClassData/tiny-imagenet-200/

# %%
import TorchClassifier
import TorchClassifier.Datasetutil
import TorchClassifier.Datasetutil.Visutil

# %%
! python TorchClassifier/myTorchTrainer.py --data_name 'tiny-imagenet-200' --data_type 'trainonly' --data_path "/data/cmpe249-fa23/ImageClassData" --model_name 'resnetmodel1' --learningratename 'StepLR' --lr 0.1 --momentum 0.9 --wd 1e-4 --optimizer 'SGD'
# Out:
# 2023-12-02 02:58:59.237290: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 02:58:59.237352: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 02:58:59.237395: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 02:59:00.787473: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.1.0+cu118
# Torch Version:  2.1.0+cu118
# Torchvision Version:  0.16.0+cu118
# Output path: ./outputs/tiny-imagenet-200_resnetmodel1_0910
# Num GPUs: 1
# 0
# Tesla T4
# True
# Num training images:  100000
# ...

# %%
! python TorchClassifier/myTorchTrainer.py --data_name 'tiny-imagenet-200' --data_type 'trainonly' --data_path "/data/cmpe249-fa23/ImageClassData" --model_name 'vit_b_32' --learningratename 'StepLR' --lr 0.1 --momentum 0.9 --wd 1e-4 --optimizer 'SGD' --batchsize 32
# Out:
# 2023-12-02 02:53:14.858151: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-02 02:53:14.858210: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-02 02:53:14.858256: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-02 02:53:15.931529: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.1.0+cu118
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/cmpe_255_homework2/MultiModalClassifier/TorchClassifier/myTorchTrainer.py", line 45, in <module>
# ...

# %%
! python TorchClassifier/myTorchTrainer.py --data_name 'tiny-imagenet-200' --data_type 'trainonly' --data_path "/data/cmpe249-fa23/ImageClassData" --model_name 'vit_b_16' --learningratename 'StepLR' --lr 0.1 --momentum 0.9 --wd 1e-4 --optimizer 'Adam' --batchsize 32 --TAG '0910'

# %%
! python TorchClassifier/myTorchTrainer.py --data_name 'flower_photos' --data_type 'traintestfolder' --data_path "/data/cmpe249-fa23/ImageClassData" --model_name 'vit_b_16' --learningratename 'StepLR' --lr 0.1 --momentum 0.9 --wd 1e-4 --optimizer 'Adam' --batchsize 64 --TAG '0916'
